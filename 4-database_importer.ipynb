# %%
import pandas as pd
import os
from glob import glob

from db import connection
from db_utils import DBUtils

# %% [markdown]
# ## Database importer

# %%
entities = pd.read_csv('./standardization/entities-standardized.csv')

# %%
with connection as c:
    
    db = DBUtils(c)
    
    all_entities = entities.copy()
    new_entities = all_entities[all_entities['db_entity_id'].isnull()]
    
    for _, entity in new_entities.iterrows():
        entity_id = entity.name
        entity_name = entity['name']
        db_entity_id = db.get_or_create_entity(entity_name)
        all_entities.loc[entity_id, 'db_entity_id'] = db_entity_id
    
    db_entity_id_by_name = { row['name']: int(row['db_entity_id']) for _, row in all_entities.iterrows() }
    
    
    # Inserting the dataset
    db_dataset_id = db.upsert_dataset(
                name="BP Statistical Review of Global Energy", 
                namespace="bpstatreview_2019", 
                user_id=35)

    #Inserting the source
    db_source_id = db.upsert_source(
        name="BP Statistical Review of Global Energy (2019)", 
        description="", 
        dataset_id=db_dataset_id)

    # Inserting variables
    variables = pd.read_csv("output/variables.csv")

    for i, variable in variables.iterrows():
        
        print("Inserting variable: %s" % variable['name'])
        db_variable_id = db.upsert_variable(
                                        name=variable['name'], 
                                        code=None, 
                                        unit=variable['unit'], 
                                        short_unit=None, 
                                        source_id=db_source_id, 
                                        dataset_id=db_dataset_id, 
                                        description=variable['notes'] if pd.notnull(variable['notes']) else ""
                                        )
        
        data_values = pd.read_csv('./output/datapoints/datapoints_%d.csv' % variable.id)
        
        values = [(float(row['value']), int(row['year']), db_entity_id_by_name[row['country']], db_variable_id)
                      for _, row in data_values.iterrows()]
        
        print("Inserting values...")
        db.upsert_many("""
            INSERT INTO data_values (value, year, entityId, variableId)
            VALUES (%s, %s, %s, %s)
        """, values)
        print("Inserted %d values for variable" % len(values))
# Out:
# Inserting variable: Biofuels Production - Kboed
# Inserting values...
# Inserted 1015 values for variable
# Inserting variable: Biofuels Production - Ktoe
# Inserting values...
# Inserted 1015 values for variable
# Inserting variable: Carbon Dioxide Emissions
# Inserting values...
# Inserted 5065 values for variable
# Inserting variable: Coal - Prices
# Inserting values...
# Inserted 126 values for variable
# Inserting variable: Coal - Reserves - Anthracite and bituminous
# Inserting values...
# Inserted 47 values for variable
# Inserting variable: Coal - Reserves - Sub-bituminous and lignite
# Inserting values...
# Inserted 47 values for variable
# Inserting variable: Coal - Reserves - Total
# Inserting values...
# Inserted 47 values for variable
# Inserting variable: Coal Consumption - Mtoe
# Inserting values...
# Inserted 5206 values for variable
# Inserting variable: Coal Production - Mtoe
# Inserting values...
# Inserted 1748 values for variable
# Inserting variable: Coal Production - Tonnes
# Inserting values...
# Inserted 1752 values for variable
# Inserting variable: Electricity Generation
# Inserting values...
# Inserted 3351 values for variable
# Inserting variable: Gas - Prices
# Inserting values...
# Inserted 80 values for variable
# Inserting variable: Gas - Proved reserves
# Inserting values...
# Inserted 260 values for variable
# Inserting variable: Gas - Proved reserves history
# Inserting values...
# Inserted 2456 values for variable
# Inserting variable: Gas Consumption - Bcf
# Inserting values...
# Inserted 5226 values for variable
# Inserting variable: Gas Consumption - Bcm
# Inserting values...
# Inserted 5226 values for variable
# Inserting variable: Gas Consumption - Mtoe
# Inserting values...
# Inserted 5226 values for variable
# Inserting variable: Gas Production - Bcf
# Inserting values...
# Inserted 3027 values for variable
# Inserting variable: Gas Production - Bcm
# Inserting values...
# Inserted 3027 values for variable
# Inserting variable: Gas Production - Mtoe
# Inserting values...
# Inserted 3027 values for variable
# Inserting variable: Geo Biomass Other - Mtoe
# Inserting values...
# Inserted 5091 values for variable
# Inserting variable: Geo Biomass Other - TWh
# Inserting values...
# Inserted 5037 values for variable
# Inserting variable: Geothermal Capacity
# Inserting values...
# Inserted 717 values for variable
# Inserting variable: Hydro Consumption - Mtoe
# Inserting values...
# Inserted 5091 values for variable
# Inserting variable: Hydro Generation - TWh
# Inserting values...
# Inserted 5091 values for variable
# Inserting variable: Nuclear Consumption - Mtoe
# Inserting values...
# Inserted 4979 values for variable
# Inserting variable: Nuclear Generation - TWh
# Inserting values...
# Inserted 4999 values for variable
# Inserting variable: Oil - Proved reserves
# Inserting values...
# Inserted 250 values for variable
# Inserting variable: Oil - Proved reserves history
# Inserting values...
# Inserted 2359 values for variable
# Inserting variable: Oil - Refinery throughput
# Inserting values...
# Inserted 3284 values for variable
# Inserting variable: Oil - Refining capacity
# Inserting values...
# Inserted 4539 values for variable
# Inserting variable: Oil - Spot crude prices
# Inserting values...
# Inserted 176 values for variable
# Inserting variable: Oil Consumption - Barrels
# Inserting values...
# Inserted 5065 values for variable
# Inserting variable: Oil Consumption - Tonnes
# Inserting values...
# Inserted 5065 values for variable
# Inserting variable: Oil Production - Barrels
# Inserting values...
# Inserted 3104 values for variable
# Inserting variable: Oil Production - Tonnes
# Inserting values...
# Inserted 3104 values for variable
# Inserting variable: Primary Energy Consumption
# Inserting values...
# Inserted 5065 values for variable
# Inserting variable: Renewables - Mtoe
# Inserting values...
# Inserted 5091 values for variable
# Inserting variable: Renewables - TWh
# Inserting values...
# Inserted 5111 values for variable
# Inserting variable: Solar Capacity
# Inserting values...
# Inserted 1353 values for variable
# Inserting variable: Solar Consumption - Mtoe
# Inserting values...
# Inserted 5091 values for variable
# Inserting variable: Solar Generation - TWh
# Inserting values...
# Inserted 5091 values for variable
# Inserting variable: Wind Capacity
# Inserting values...
# Inserted 1329 values for variable
# Inserting variable: Wind Consumption - Mtoe
# Inserting values...
# Inserted 5091 values for variable
# Inserting variable: Wind Generation - TWh
# Inserting values...
# Inserted 5091 values for variable
# Inserting variable: Cobalt and Lithium - Prices - Cobalt
# Inserting values...
# Inserted 19 values for variable
# Inserting variable: Cobalt and Lithium - Prices - Lithium Carbonate
# Inserting values...
# Inserted 19 values for variable
# Inserting variable: Cobalt Production-Reserves - Production
# Inserting values...
# Inserted 303 values for variable
# Inserting variable: Cobalt Production-Reserves - Reserves
# Inserting values...
# Inserted 14 values for variable
# Inserting variable: Elec Gen by fuel - Oil
# Inserting values...
# Inserted 88 values for variable
# Inserting variable: Elec Gen by fuel - Natural Gas
# Inserting values...
# Inserted 88 values for variable
# Inserting variable: Elec Gen by fuel - Coal
# Inserting values...
# Inserted 88 values for variable
# Inserting variable: Elec Gen by fuel - Nuclear energy
# Inserting values...
# Inserted 88 values for variable
# Inserting variable: Elec Gen by fuel - Hydro electric
# Inserting values...
# Inserted 88 values for variable
# Inserting variable: Elec Gen by fuel - Renewables
# Inserting values...
# Inserted 88 values for variable
# Inserting variable: Elec Gen by fuel - Other #
# Inserting values...
# Inserted 88 values for variable
# Inserting variable: Elec Gen by fuel - Total
# Inserting values...
# Inserted 88 values for variable
# Inserting variable: Elec Gen from Coal
# Inserting values...
# Inserted 1496 values for variable
# Inserting variable: Elec Gen from Gas
# Inserting values...
# Inserted 1496 values for variable
# Inserting variable: Elec Gen from Oil
# Inserting values...
# Inserted 1496 values for variable
# Inserting variable: Elec Gen from Other
# Inserting values...
# Inserted 1496 values for variable
# Inserting variable: Graphite Production-Reserves
# Inserting values...
# Inserted 295 values for variable
# Inserting variable: Lithium Production-Reserves
# Inserting values...
# Inserted 233 values for variable
# Inserting variable: Oil - Crude prices since 1861
# Inserting values...
# Inserted 158 values for variable
# Inserting variable: Oil Consumption - Mtoe
# Inserting values...
# Inserted 5065 values for variable
# Inserting variable: Primary Energy - Cons by fuel - Oil
# Inserting values...
# Inserted 160 values for variable
# Inserting variable: Primary Energy - Cons by fuel - Natural Gas
# Inserting values...
# Inserted 160 values for variable
# Inserting variable: Primary Energy - Cons by fuel - Coal
# Inserting values...
# Inserted 160 values for variable
# Inserting variable: Primary Energy - Cons by fuel - Nuclear energy
# Inserting values...
# Inserted 160 values for variable
# Inserting variable: Primary Energy - Cons by fuel - Hydro electric
# Inserting values...
# Inserted 160 values for variable
# Inserting variable: Primary Energy - Cons by fuel - Renewables
# Inserting values...
# Inserted 160 values for variable
# Inserting variable: Primary Energy - Cons by fuel - Total
# Inserting values...
# Inserted 160 values for variable
# Inserting variable: Primary Energy - Cons capita
# Inserting values...
# Inserted 5065 values for variable
# Inserting variable: Rare Earth Production-Reserves
# Inserting values...
# Inserted 192 values for variable
# Inserting variable: Renewables Generation by source - Wind
# Inserting values...
# Inserted 160 values for variable
# Inserting variable: Renewables Generation by source - Solar
# Inserting values...
# Inserted 160 values for variable
# Inserting variable: Renewables Generation by source - Other renewables+
# Inserting values...
# Inserted 160 values for variable
# Inserting variable: Renewables Generation by source - Total
# Inserting values...
# Inserted 160 values for variable
